# %%
from Bio import SeqIO
from datasketch import MinHash, MinHashLSH
import os

# %%
def split_fasta(input_fasta, output_dir, batch_size=50000):
    os.makedirs(output_dir, exist_ok=True)
    records = list(SeqIO.parse(input_fasta, "fasta"))
    total = len(records)
    print(f"Total sequences: {total}")

    batch_count = 0
    for i in range(0, total, batch_size):
        batch_records = records[i:i+batch_size]
        batch_file = os.path.join(output_dir, f"batch_{batch_count}.fasta")
        SeqIO.write(batch_records, batch_file, "fasta")
        print(f"Saved batch {batch_count} with {len(batch_records)} sequences")
        batch_count += 1

    return batch_count

# %%
def get_minhash(sequence, num_perm=128, ksize=3):
    mh = MinHash(num_perm=num_perm)
    for i in range(len(sequence) - ksize + 1):
        kmer = sequence[i:i+ksize]
        mh.update(kmer.encode('utf8'))
    return mh

def sequence_identity(seq1, seq2):
    length = min(len(seq1), len(seq2))
    matches = sum(a == b for a, b in zip(seq1[:length], seq2[:length]))
    return matches / length * 100

def deduplicate_batch(input_fasta, output_fasta, similarity=98.0, ksize=3, num_perm=128):
    records = list(SeqIO.parse(input_fasta, "fasta"))

    lsh = MinHashLSH(threshold=similarity/100, num_perm=num_perm)
    minhashes = {}
    id_to_record = {}

    for idx, record in enumerate(records):
        seq_str = str(record.seq)
        mh = get_minhash(seq_str, num_perm=num_perm, ksize=ksize)
        key = f"seq_{idx}"
        lsh.insert(key, mh)
        minhashes[key] = mh
        id_to_record[key] = record

    visited = set()
    representatives = []

    for key in minhashes:
        if key not in visited:
            similar_keys = lsh.query(minhashes[key])
            similar_records = [id_to_record[k] for k in similar_keys]

            group_representatives = []
            for record in similar_records:
                seq = str(record.seq)
                is_similar = False
                for kept in group_representatives:
                    kept_seq = str(kept.seq)
                    if sequence_identity(seq, kept_seq) >= similarity:
                        is_similar = True
                        break
                if not is_similar:
                    group_representatives.append(record)
            
            representatives.extend(group_representatives)
            visited.update(similar_keys)

    SeqIO.write(representatives, output_fasta, "fasta")
    print(f"Batch deduplicated: {len(representatives)} sequences saved to {output_fasta}")

# %%
def merge_batches(batch_dir, merged_output):
    batch_files = sorted([os.path.join(batch_dir, f) for f in os.listdir(batch_dir) if f.endswith(".fasta")])

    all_records = []
    for batch_file in batch_files:
        batch_records = list(SeqIO.parse(batch_file, "fasta"))
        all_records.extend(batch_records)

    SeqIO.write(all_records, merged_output, "fasta")
    print(f"Merged {len(batch_files)} batches into {merged_output} ({len(all_records)} sequences)")

# %%
input_fasta = "output_fragments_284.fasta"
batch_dir = "batches"
merged_fasta = "merged_batches.fasta"
final_output = "final_filtered_peptides.fasta"

# 1. Split
split_fasta(input_fasta, batch_dir, batch_size=50000)

# 2. Deduplicate từng batch
batch_files = [os.path.join(batch_dir, f) for f in os.listdir(batch_dir) if f.endswith(".fasta")]
for batch_file in batch_files:
    output_batch = batch_file.replace(".fasta", "_filtered.fasta")
    deduplicate_batch(batch_file, output_batch, similarity=98.0)

# 3. Merge các batch đã lọc
merge_batches(batch_dir, merged_fasta)

# 4. Deduplicate lần cuối
deduplicate_batch(merged_fasta, final_output, similarity=98.0)
print("ALL DONE!")
# Out:
# Total sequences: 22358248
# Saved batch 0 with 50000 sequences
# Saved batch 1 with 50000 sequences
# Saved batch 2 with 50000 sequences
# Saved batch 3 with 50000 sequences
# Saved batch 4 with 50000 sequences
# Saved batch 5 with 50000 sequences
# Saved batch 6 with 50000 sequences
# Saved batch 7 with 50000 sequences
# Saved batch 8 with 50000 sequences
# Saved batch 9 with 50000 sequences
# Saved batch 10 with 50000 sequences
# Saved batch 11 with 50000 sequences
# Saved batch 12 with 50000 sequences
# Saved batch 13 with 50000 sequences
# Saved batch 14 with 50000 sequences
# Saved batch 15 with 50000 sequences
# Saved batch 16 with 50000 sequences
# Saved batch 17 with 50000 sequences
# Saved batch 18 with 50000 sequences
# Saved batch 19 with 50000 sequences
# Saved batch 20 with 50000 sequences
# Saved batch 21 with 50000 sequences
# Saved batch 22 with 50000 sequences
# Saved batch 23 with 50000 sequences
# Saved batch 24 with 50000 sequences
# Saved batch 25 with 50000 sequences
# Saved batch 26 with 50000 sequences
# Saved batch 27 with 50000 sequences
# Saved batch 28 with 50000 sequences
# Saved batch 29 with 50000 sequences
# Saved batch 30 with 50000 sequences
# Saved batch 31 with 50000 sequences
# Saved batch 32 with 50000 sequences
# Saved batch 33 with 50000 sequences
# Saved batch 34 with 50000 sequences
# Saved batch 35 with 50000 sequences
# Saved batch 36 with 50000 sequences
# Saved batch 37 with 50000 sequences
# Saved batch 38 with 50000 sequences
# Saved batch 39 with 50000 sequences
# Saved batch 40 with 50000 sequences
# Saved batch 41 with 50000 sequences
# Saved batch 42 with 50000 sequences
# Saved batch 43 with 50000 sequences
# Saved batch 44 with 50000 sequences
# Saved batch 45 with 50000 sequences
# Saved batch 46 with 50000 sequences
# Saved batch 47 with 50000 sequences
# Saved batch 48 with 50000 sequences
# Saved batch 49 with 50000 sequences
# Saved batch 50 with 50000 sequences
# Saved batch 51 with 50000 sequences
# Saved batch 52 with 50000 sequences
# Saved batch 53 with 50000 sequences
# Saved batch 54 with 50000 sequences
# Saved batch 55 with 50000 sequences
# Saved batch 56 with 50000 sequences
# Saved batch 57 with 50000 sequences
# Saved batch 58 with 50000 sequences
# Saved batch 59 with 50000 sequences
# Saved batch 60 with 50000 sequences
# Saved batch 61 with 50000 sequences
# Saved batch 62 with 50000 sequences
# Saved batch 63 with 50000 sequences
# Saved batch 64 with 50000 sequences
# Saved batch 65 with 50000 sequences
# Saved batch 66 with 50000 sequences
# Saved batch 67 with 50000 sequences
# Saved batch 68 with 50000 sequences
# Saved batch 69 with 50000 sequences
# Saved batch 70 with 50000 sequences
# Saved batch 71 with 50000 sequences
# Saved batch 72 with 50000 sequences
# Saved batch 73 with 50000 sequences
# Saved batch 74 with 50000 sequences
# Saved batch 75 with 50000 sequences
# Saved batch 76 with 50000 sequences
# Saved batch 77 with 50000 sequences
# Saved batch 78 with 50000 sequences
# Saved batch 79 with 50000 sequences
# Saved batch 80 with 50000 sequences
# Saved batch 81 with 50000 sequences
# Saved batch 82 with 50000 sequences
# Saved batch 83 with 50000 sequences
# Saved batch 84 with 50000 sequences
# Saved batch 85 with 50000 sequences
# Saved batch 86 with 50000 sequences
# Saved batch 87 with 50000 sequences
# Saved batch 88 with 50000 sequences
# Saved batch 89 with 50000 sequences
# Saved batch 90 with 50000 sequences
# Saved batch 91 with 50000 sequences
# Saved batch 92 with 50000 sequences
# Saved batch 93 with 50000 sequences
# Saved batch 94 with 50000 sequences
# Saved batch 95 with 50000 sequences
# Saved batch 96 with 50000 sequences
# Saved batch 97 with 50000 sequences
# Saved batch 98 with 50000 sequences
# Saved batch 99 with 50000 sequences
# Saved batch 100 with 50000 sequences
# Saved batch 101 with 50000 sequences
# Saved batch 102 with 50000 sequences
# Saved batch 103 with 50000 sequences
# Saved batch 104 with 50000 sequences
# Saved batch 105 with 50000 sequences
# Saved batch 106 with 50000 sequences
# Saved batch 107 with 50000 sequences
# Saved batch 108 with 50000 sequences
# Saved batch 109 with 50000 sequences
# Saved batch 110 with 50000 sequences
# Saved batch 111 with 50000 sequences
# Saved batch 112 with 50000 sequences
# Saved batch 113 with 50000 sequences
# Saved batch 114 with 50000 sequences
# Saved batch 115 with 50000 sequences
# Saved batch 116 with 50000 sequences
# Saved batch 117 with 50000 sequences
# Saved batch 118 with 50000 sequences
# Saved batch 119 with 50000 sequences
# Saved batch 120 with 50000 sequences
# Saved batch 121 with 50000 sequences
# Saved batch 122 with 50000 sequences
# Saved batch 123 with 50000 sequences
# Saved batch 124 with 50000 sequences
# Saved batch 125 with 50000 sequences
# Saved batch 126 with 50000 sequences
# Saved batch 127 with 50000 sequences
# Saved batch 128 with 50000 sequences
# Saved batch 129 with 50000 sequences
# Saved batch 130 with 50000 sequences
# Saved batch 131 with 50000 sequences
# Saved batch 132 with 50000 sequences
# Saved batch 133 with 50000 sequences
# Saved batch 134 with 50000 sequences
# Saved batch 135 with 50000 sequences
# Saved batch 136 with 50000 sequences
# Saved batch 137 with 50000 sequences
# Saved batch 138 with 50000 sequences
# Saved batch 139 with 50000 sequences
# Saved batch 140 with 50000 sequences
# Saved batch 141 with 50000 sequences
# Saved batch 142 with 50000 sequences
# Saved batch 143 with 50000 sequences
# Saved batch 144 with 50000 sequences
# Saved batch 145 with 50000 sequences
# Saved batch 146 with 50000 sequences
# Saved batch 147 with 50000 sequences
# Saved batch 148 with 50000 sequences
# Saved batch 149 with 50000 sequences
# Saved batch 150 with 50000 sequences
# Saved batch 151 with 50000 sequences
# Saved batch 152 with 50000 sequences
# Saved batch 153 with 50000 sequences
# Saved batch 154 with 50000 sequences
# Saved batch 155 with 50000 sequences
# Saved batch 156 with 50000 sequences
# Saved batch 157 with 50000 sequences
# Saved batch 158 with 50000 sequences
# Saved batch 159 with 50000 sequences
# Saved batch 160 with 50000 sequences
# Saved batch 161 with 50000 sequences
# Saved batch 162 with 50000 sequences
# Saved batch 163 with 50000 sequences
# Saved batch 164 with 50000 sequences
# Saved batch 165 with 50000 sequences
# Saved batch 166 with 50000 sequences
# Saved batch 167 with 50000 sequences
# Saved batch 168 with 50000 sequences
# Saved batch 169 with 50000 sequences
# Saved batch 170 with 50000 sequences
# Saved batch 171 with 50000 sequences
# Saved batch 172 with 50000 sequences
# Saved batch 173 with 50000 sequences
# Saved batch 174 with 50000 sequences
# Saved batch 175 with 50000 sequences
# Saved batch 176 with 50000 sequences
# Saved batch 177 with 50000 sequences
# Saved batch 178 with 50000 sequences
# Saved batch 179 with 50000 sequences
# Saved batch 180 with 50000 sequences
# Saved batch 181 with 50000 sequences
# Saved batch 182 with 50000 sequences
# Saved batch 183 with 50000 sequences
# Saved batch 184 with 50000 sequences
# Saved batch 185 with 50000 sequences
# Saved batch 186 with 50000 sequences
# Saved batch 187 with 50000 sequences
# Saved batch 188 with 50000 sequences
# Saved batch 189 with 50000 sequences
# Saved batch 190 with 50000 sequences
# Saved batch 191 with 50000 sequences
# Saved batch 192 with 50000 sequences
# Saved batch 193 with 50000 sequences
# Saved batch 194 with 50000 sequences
# Saved batch 195 with 50000 sequences
# Saved batch 196 with 50000 sequences
# Saved batch 197 with 50000 sequences
# Saved batch 198 with 50000 sequences
# Saved batch 199 with 50000 sequences
# Saved batch 200 with 50000 sequences
# Saved batch 201 with 50000 sequences
# Saved batch 202 with 50000 sequences
# Saved batch 203 with 50000 sequences
# Saved batch 204 with 50000 sequences
# Saved batch 205 with 50000 sequences
# Saved batch 206 with 50000 sequences
# Saved batch 207 with 50000 sequences
# Saved batch 208 with 50000 sequences
# Saved batch 209 with 50000 sequences
# Saved batch 210 with 50000 sequences
# Saved batch 211 with 50000 sequences
# Saved batch 212 with 50000 sequences
# Saved batch 213 with 50000 sequences
# Saved batch 214 with 50000 sequences
# Saved batch 215 with 50000 sequences
# Saved batch 216 with 50000 sequences
# Saved batch 217 with 50000 sequences
# Saved batch 218 with 50000 sequences
# Saved batch 219 with 50000 sequences
# Saved batch 220 with 50000 sequences
# Saved batch 221 with 50000 sequences
# Saved batch 222 with 50000 sequences
# Saved batch 223 with 50000 sequences
# Saved batch 224 with 50000 sequences
# Saved batch 225 with 50000 sequences
# Saved batch 226 with 50000 sequences
# Saved batch 227 with 50000 sequences
# Saved batch 228 with 50000 sequences
# Saved batch 229 with 50000 sequences
# Saved batch 230 with 50000 sequences
# Saved batch 231 with 50000 sequences
# Saved batch 232 with 50000 sequences
# Saved batch 233 with 50000 sequences
# Saved batch 234 with 50000 sequences
# Saved batch 235 with 50000 sequences
# Saved batch 236 with 50000 sequences
# Saved batch 237 with 50000 sequences
# Saved batch 238 with 50000 sequences
# Saved batch 239 with 50000 sequences
# Saved batch 240 with 50000 sequences
# Saved batch 241 with 50000 sequences
# Saved batch 242 with 50000 sequences
# Saved batch 243 with 50000 sequences
# Saved batch 244 with 50000 sequences
# Saved batch 245 with 50000 sequences
# Saved batch 246 with 50000 sequences
# Saved batch 247 with 50000 sequences
# Saved batch 248 with 50000 sequences
# Saved batch 249 with 50000 sequences
# Saved batch 250 with 50000 sequences
# Saved batch 251 with 50000 sequences
# Saved batch 252 with 50000 sequences
# Saved batch 253 with 50000 sequences
# Saved batch 254 with 50000 sequences
# Saved batch 255 with 50000 sequences
# Saved batch 256 with 50000 sequences
# Saved batch 257 with 50000 sequences
# Saved batch 258 with 50000 sequences
# Saved batch 259 with 50000 sequences
# Saved batch 260 with 50000 sequences
# Saved batch 261 with 50000 sequences
# Saved batch 262 with 50000 sequences
# Saved batch 263 with 50000 sequences
# Saved batch 264 with 50000 sequences
# Saved batch 265 with 50000 sequences
# Saved batch 266 with 50000 sequences
# Saved batch 267 with 50000 sequences
# Saved batch 268 with 50000 sequences
# Saved batch 269 with 50000 sequences
# Saved batch 270 with 50000 sequences
# Saved batch 271 with 50000 sequences
# Saved batch 272 with 50000 sequences
# Saved batch 273 with 50000 sequences
# Saved batch 274 with 50000 sequences
# Saved batch 275 with 50000 sequences
# Saved batch 276 with 50000 sequences
# Saved batch 277 with 50000 sequences
# Saved batch 278 with 50000 sequences
# Saved batch 279 with 50000 sequences
# Saved batch 280 with 50000 sequences
# Saved batch 281 with 50000 sequences
# Saved batch 282 with 50000 sequences
# Saved batch 283 with 50000 sequences
# Saved batch 284 with 50000 sequences
# Saved batch 285 with 50000 sequences
# Saved batch 286 with 50000 sequences
# Saved batch 287 with 50000 sequences
# Saved batch 288 with 50000 sequences
# Saved batch 289 with 50000 sequences
# Saved batch 290 with 50000 sequences
# Saved batch 291 with 50000 sequences
# Saved batch 292 with 50000 sequences
# Saved batch 293 with 50000 sequences
# Saved batch 294 with 50000 sequences
# Saved batch 295 with 50000 sequences
# Saved batch 296 with 50000 sequences
# Saved batch 297 with 50000 sequences
# Saved batch 298 with 50000 sequences
# Saved batch 299 with 50000 sequences
# Saved batch 300 with 50000 sequences
# Saved batch 301 with 50000 sequences
# Saved batch 302 with 50000 sequences
# Saved batch 303 with 50000 sequences
# Saved batch 304 with 50000 sequences
# Saved batch 305 with 50000 sequences
# Saved batch 306 with 50000 sequences
# Saved batch 307 with 50000 sequences
# Saved batch 308 with 50000 sequences
# Saved batch 309 with 50000 sequences
# Saved batch 310 with 50000 sequences
# Saved batch 311 with 50000 sequences
# Saved batch 312 with 50000 sequences
# Saved batch 313 with 50000 sequences
# Saved batch 314 with 50000 sequences
# Saved batch 315 with 50000 sequences
# Saved batch 316 with 50000 sequences
# Saved batch 317 with 50000 sequences
# Saved batch 318 with 50000 sequences
# Saved batch 319 with 50000 sequences
# Saved batch 320 with 50000 sequences
# Saved batch 321 with 50000 sequences
# Saved batch 322 with 50000 sequences
# Saved batch 323 with 50000 sequences
# Saved batch 324 with 50000 sequences
# Saved batch 325 with 50000 sequences
# Saved batch 326 with 50000 sequences
# Saved batch 327 with 50000 sequences
# Saved batch 328 with 50000 sequences
# Saved batch 329 with 50000 sequences
# Saved batch 330 with 50000 sequences
# Saved batch 331 with 50000 sequences
# Saved batch 332 with 50000 sequences
# Saved batch 333 with 50000 sequences
# Saved batch 334 with 50000 sequences
# Saved batch 335 with 50000 sequences
# Saved batch 336 with 50000 sequences
# Saved batch 337 with 50000 sequences
# Saved batch 338 with 50000 sequences
# Saved batch 339 with 50000 sequences
# Saved batch 340 with 50000 sequences
# Saved batch 341 with 50000 sequences
# Saved batch 342 with 50000 sequences
# Saved batch 343 with 50000 sequences
# Saved batch 344 with 50000 sequences
# Saved batch 345 with 50000 sequences
# Saved batch 346 with 50000 sequences
# Saved batch 347 with 50000 sequences
# Saved batch 348 with 50000 sequences
# Saved batch 349 with 50000 sequences
# Saved batch 350 with 50000 sequences
# Saved batch 351 with 50000 sequences
# Saved batch 352 with 50000 sequences
# Saved batch 353 with 50000 sequences
# Saved batch 354 with 50000 sequences
# Saved batch 355 with 50000 sequences
# Saved batch 356 with 50000 sequences
# Saved batch 357 with 50000 sequences
# Saved batch 358 with 50000 sequences
# Saved batch 359 with 50000 sequences
# Saved batch 360 with 50000 sequences
# Saved batch 361 with 50000 sequences
# Saved batch 362 with 50000 sequences
# Saved batch 363 with 50000 sequences
# Saved batch 364 with 50000 sequences
# Saved batch 365 with 50000 sequences
# Saved batch 366 with 50000 sequences
# Saved batch 367 with 50000 sequences
# Saved batch 368 with 50000 sequences
# Saved batch 369 with 50000 sequences
# Saved batch 370 with 50000 sequences
# Saved batch 371 with 50000 sequences
# Saved batch 372 with 50000 sequences
# Saved batch 373 with 50000 sequences
# Saved batch 374 with 50000 sequences
# Saved batch 375 with 50000 sequences
# Saved batch 376 with 50000 sequences
# Saved batch 377 with 50000 sequences
# Saved batch 378 with 50000 sequences
# Saved batch 379 with 50000 sequences
# Saved batch 380 with 50000 sequences
# Saved batch 381 with 50000 sequences
# Saved batch 382 with 50000 sequences
# Saved batch 383 with 50000 sequences
# Saved batch 384 with 50000 sequences
# Saved batch 385 with 50000 sequences
# Saved batch 386 with 50000 sequences
# Saved batch 387 with 50000 sequences
# Saved batch 388 with 50000 sequences
# Saved batch 389 with 50000 sequences
# Saved batch 390 with 50000 sequences
# Saved batch 391 with 50000 sequences
# Saved batch 392 with 50000 sequences
# Saved batch 393 with 50000 sequences
# Saved batch 394 with 50000 sequences
# Saved batch 395 with 50000 sequences
# Saved batch 396 with 50000 sequences
# Saved batch 397 with 50000 sequences
# Saved batch 398 with 50000 sequences
# Saved batch 399 with 50000 sequences
# Saved batch 400 with 50000 sequences
# Saved batch 401 with 50000 sequences
# Saved batch 402 with 50000 sequences
# Saved batch 403 with 50000 sequences
# Saved batch 404 with 50000 sequences
# Saved batch 405 with 50000 sequences
# Saved batch 406 with 50000 sequences
# Saved batch 407 with 50000 sequences
# Saved batch 408 with 50000 sequences
# Saved batch 409 with 50000 sequences
# Saved batch 410 with 50000 sequences
# Saved batch 411 with 50000 sequences
# Saved batch 412 with 50000 sequences
# Saved batch 413 with 50000 sequences
# Saved batch 414 with 50000 sequences
# Saved batch 415 with 50000 sequences
# Saved batch 416 with 50000 sequences
# Saved batch 417 with 50000 sequences
# Saved batch 418 with 50000 sequences
# Saved batch 419 with 50000 sequences
# Saved batch 420 with 50000 sequences
# Saved batch 421 with 50000 sequences
# Saved batch 422 with 50000 sequences
# Saved batch 423 with 50000 sequences
# Saved batch 424 with 50000 sequences
# Saved batch 425 with 50000 sequences
# Saved batch 426 with 50000 sequences
# Saved batch 427 with 50000 sequences
# Saved batch 428 with 50000 sequences
# Saved batch 429 with 50000 sequences
# Saved batch 430 with 50000 sequences
# Saved batch 431 with 50000 sequences
# Saved batch 432 with 50000 sequences
# Saved batch 433 with 50000 sequences
# Saved batch 434 with 50000 sequences
# Saved batch 435 with 50000 sequences
# Saved batch 436 with 50000 sequences
# Saved batch 437 with 50000 sequences
# Saved batch 438 with 50000 sequences
# Saved batch 439 with 50000 sequences
# Saved batch 440 with 50000 sequences
# Saved batch 441 with 50000 sequences
# Saved batch 442 with 50000 sequences
# Saved batch 443 with 50000 sequences
# Saved batch 444 with 50000 sequences
# Saved batch 445 with 50000 sequences
# Saved batch 446 with 50000 sequences
# Saved batch 447 with 8248 sequences
# Batch deduplicated: 49778 sequences saved to batches\batch_0_filtered.fasta
# Batch deduplicated: 49976 sequences saved to batches\batch_1_filtered.fasta
# Batch deduplicated: 49758 sequences saved to batches\batch_10_filtered.fasta
# Batch deduplicated: 45854 sequences saved to batches\batch_100_filtered.fasta
# Batch deduplicated: 49778 sequences saved to batches\batch_101_filtered.fasta
# Batch deduplicated: 44916 sequences saved to batches\batch_102_filtered.fasta
# Batch deduplicated: 34824 sequences saved to batches\batch_103_filtered.fasta
# Batch deduplicated: 42453 sequences saved to batches\batch_104_filtered.fasta
# Batch deduplicated: 43243 sequences saved to batches\batch_105_filtered.fasta
# Batch deduplicated: 41923 sequences saved to batches\batch_106_filtered.fasta
# Batch deduplicated: 41108 sequences saved to batches\batch_107_filtered.fasta
# Batch deduplicated: 40172 sequences saved to batches\batch_108_filtered.fasta
# Batch deduplicated: 45148 sequences saved to batches\batch_109_filtered.fasta
# Batch deduplicated: 48611 sequences saved to batches\batch_11_filtered.fasta
# Batch deduplicated: 49680 sequences saved to batches\batch_110_filtered.fasta
# Batch deduplicated: 49817 sequences saved to batches\batch_111_filtered.fasta
# Batch deduplicated: 46944 sequences saved to batches\batch_112_filtered.fasta
# Batch deduplicated: 45042 sequences saved to batches\batch_113_filtered.fasta
# Batch deduplicated: 49631 sequences saved to batches\batch_114_filtered.fasta
# Batch deduplicated: 49752 sequences saved to batches\batch_115_filtered.fasta
# Batch deduplicated: 48235 sequences saved to batches\batch_116_filtered.fasta
# Batch deduplicated: 48242 sequences saved to batches\batch_117_filtered.fasta
# Batch deduplicated: 47136 sequences saved to batches\batch_118_filtered.fasta
# Batch deduplicated: 47699 sequences saved to batches\batch_119_filtered.fasta
# Batch deduplicated: 42105 sequences saved to batches\batch_12_filtered.fasta
# Batch deduplicated: 39166 sequences saved to batches\batch_120_filtered.fasta
# Batch deduplicated: 31174 sequences saved to batches\batch_121_filtered.fasta
# Batch deduplicated: 49621 sequences saved to batches\batch_122_filtered.fasta
# Batch deduplicated: 49312 sequences saved to batches\batch_123_filtered.fasta
# Batch deduplicated: 49821 sequences saved to batches\batch_124_filtered.fasta
# Batch deduplicated: 48693 sequences saved to batches\batch_125_filtered.fasta
# Batch deduplicated: 49662 sequences saved to batches\batch_126_filtered.fasta
# Batch deduplicated: 49797 sequences saved to batches\batch_127_filtered.fasta
# Batch deduplicated: 49810 sequences saved to batches\batch_128_filtered.fasta
# Batch deduplicated: 49878 sequences saved to batches\batch_129_filtered.fasta
# Batch deduplicated: 48533 sequences saved to batches\batch_13_filtered.fasta
# Batch deduplicated: 49924 sequences saved to batches\batch_130_filtered.fasta
# Batch deduplicated: 49669 sequences saved to batches\batch_131_filtered.fasta
# Batch deduplicated: 49853 sequences saved to batches\batch_132_filtered.fasta
# Batch deduplicated: 49701 sequences saved to batches\batch_133_filtered.fasta
# Batch deduplicated: 49513 sequences saved to batches\batch_134_filtered.fasta
# Batch deduplicated: 49283 sequences saved to batches\batch_135_filtered.fasta
# Batch deduplicated: 49876 sequences saved to batches\batch_136_filtered.fasta
# Batch deduplicated: 49696 sequences saved to batches\batch_137_filtered.fasta
# Batch deduplicated: 49621 sequences saved to batches\batch_138_filtered.fasta
# Batch deduplicated: 49911 sequences saved to batches\batch_139_filtered.fasta
# Batch deduplicated: 49427 sequences saved to batches\batch_14_filtered.fasta
# Batch deduplicated: 46618 sequences saved to batches\batch_140_filtered.fasta
# Batch deduplicated: 42918 sequences saved to batches\batch_141_filtered.fasta
# Batch deduplicated: 49485 sequences saved to batches\batch_142_filtered.fasta
# Batch deduplicated: 49880 sequences saved to batches\batch_143_filtered.fasta
# Batch deduplicated: 49810 sequences saved to batches\batch_144_filtered.fasta
# Batch deduplicated: 49867 sequences saved to batches\batch_145_filtered.fasta
# Batch deduplicated: 49808 sequences saved to batches\batch_146_filtered.fasta
# Batch deduplicated: 49938 sequences saved to batches\batch_147_filtered.fasta
# Batch deduplicated: 49859 sequences saved to batches\batch_148_filtered.fasta
# Batch deduplicated: 49903 sequences saved to batches\batch_149_filtered.fasta
# Batch deduplicated: 49731 sequences saved to batches\batch_15_filtered.fasta
# Batch deduplicated: 42639 sequences saved to batches\batch_150_filtered.fasta
# Batch deduplicated: 34265 sequences saved to batches\batch_151_filtered.fasta
# Batch deduplicated: 32323 sequences saved to batches\batch_152_filtered.fasta
# Batch deduplicated: 31214 sequences saved to batches\batch_153_filtered.fasta
# Batch deduplicated: 45748 sequences saved to batches\batch_154_filtered.fasta
# Batch deduplicated: 49385 sequences saved to batches\batch_155_filtered.fasta
# Batch deduplicated: 48222 sequences saved to batches\batch_156_filtered.fasta
# Batch deduplicated: 41400 sequences saved to batches\batch_157_filtered.fasta
# Batch deduplicated: 37851 sequences saved to batches\batch_158_filtered.fasta
# Batch deduplicated: 36018 sequences saved to batches\batch_159_filtered.fasta
# Batch deduplicated: 47905 sequences saved to batches\batch_16_filtered.fasta
# Batch deduplicated: 45828 sequences saved to batches\batch_160_filtered.fasta
# Batch deduplicated: 49981 sequences saved to batches\batch_161_filtered.fasta
# Batch deduplicated: 49996 sequences saved to batches\batch_162_filtered.fasta
# Batch deduplicated: 49867 sequences saved to batches\batch_163_filtered.fasta
